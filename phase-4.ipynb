# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr1 = np.array([1,2,3,4,5])
arr2 = np.random.rand(3,3)
arr3 = np.zeros((4,4))

# %%
np.save('arr1.py', arr1)
np.save('arr2.py', arr2)
np.save('arr3.py', arr3)

# %%
loaded_arr1 = np.load("/Users/kaushalverma/Documents/app-builder/Numpy/arr1.py.npy")
print(loaded_arr1)
# Out:
# [1 2 3 4 5]

# %%
# try:
#     logo = np.load("")

#     # Display 
#     plt.figure(figsize=(10,5))
#     plt.subplot(121)
#     plt.imshow(logo)
#     plt.title("Numpy Logo")
#     plt.grid(False)
# except FileNotFoundError:
#     print("Numpy Logo file not foung")
